# %% [markdown]
# # Environment setup

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
# !conda --version
# !which conda

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Assuming the project is in a folder called ControlNet, this needs to be adjusted based on the folder location in Google Drive.

# %%
# %cd /content/drive/MyDrive/ControlNet

# %%
# !pwd

# %%
# !conda env update -n base --file environment.yml

# %% [markdown]
# # Train

# %% [markdown]
# 184000
#
# hog, pig, grunter, squealer, Sus scrofa
#
# (64, 64, 3)
#
# (64, 64, 3)
#
# should be the output with of the next cell

# %%
# !python tutorial_dataset_test.py
# Out:
# 184000
# hog, pig, grunter, squealer, Sus scrofa
# (64, 64, 3)
# (64, 64, 3)

# %% [markdown]
# Add ControlNet to StableDiffusion ( assuming the model is uploaded in ControlNet/models )

# %%
# !python tool_add_control.py ./models/v1-5-pruned.ckpt ./models/control_sd15_ini.ckpt

# %%
# !python tutorial_train.py
